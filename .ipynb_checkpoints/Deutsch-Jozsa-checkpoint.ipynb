# %%
from qiskit import __version__

print(__version__)
# Out:
# 1.3.3

# %%
import numpy as np

x = np.random.randint(0,2)
print(x)
# Out:
# 0

# %%
from qiskit import QuantumCircuit

num_qubits = 4
print(2**num_qubits // 2)
qc = QuantumCircuit(num_qubits+1)

if np.random.randint(0,2):
    # # Flip output qubit with 50% chance
    qc.x(num_qubits)
# if np.random.randint(0,2):
#     # return constant circuit with 50% chance
#     return qc

qc.mcx(list(range(num_qubits)), num_qubits)
display(qc.draw('mpl'))
# Out:
# 8

# %%
qc = QuantumCircuit(num_qubits+1)
qc.x(range(num_qubits))
display(qc.draw('mpl'))

# %%
qc = QuantumCircuit(num_qubits+1)
display(qc.draw('mpl'))

# %%
# A Simple example of Deutsh-Jozsa Oracle function 
# f(x) = 0 or f(x) = 1 (constant) with 50% and f(x) = x_1 xor x_2 (balanced) with 50%

def deutsch_jozsa_function(num_qubits: int):
    f = QuantumCircuit(num_qubits+1)

    if np.random.randint(0, 2):
        if np.random.randint(0, 2):
            f.x(range(num_qubits))
        else:
            return f
    else:
        for i in (0, num_qubits):
            f.cx(i, num_qubits)
    return f

# %%
# Deutsch-Jozsa function for f(x) = 0 or 1 or x_1 xor x_2
display(deutsch_jozsa_function(2).draw('mpl'))
